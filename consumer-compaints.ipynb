# %%
# %matplotlib inline
import math
import random
import statistics as st
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
consumer_complaints = pd.read_csv('complaints_dec_2014.csv')
consumer_complaints.head()
# Out:
#    Complaint ID          Product Sub-product  \
# 0       1177167  Debt collection         NaN
# 1       1177166  Debt collection         NaN
# 2       1177165  Debt collection         NaN
# 3       1177164  Debt collection         NaN
# 4       1177163  Debt collection         NaN
#
#                                    Issue         Sub-issue State  ZIP code  \
# 0  Cont'd attempts collect debt not owed  Debt is not mine    TX   77068.0
# 1  Cont'd attempts collect debt not owed  Debt is not mine    TX   77068.0
# 2  Cont'd attempts collect debt not owed  Debt is not mine    TX   77068.0
# 3  Cont'd attempts collect debt not owed  Debt is not mine    TX   77068.0
# 4  Cont'd attempts collect debt not owed  Debt is not mine    TX   77068.0
#
#   Submitted via Date received Date sent to company  \
# 0           Web    12/31/2014           12/31/2014
# 1           Web    12/31/2014           12/31/2014
# 2           Web    12/31/2014           12/31/2014
# 3           Web    12/31/2014           12/31/2014
# 4           Web    12/31/2014           12/31/2014
#
#                            Company                 Company response  \
# 0   Ad Astra Recovery Services Inc          Closed with explanation
# 1  Unique Management Services, Inc          Closed with explanation
# 2                 CL Holdings, LLC      Closed with monetary relief
# 3   Enhanced Recovery Company, LLC  Closed with non-monetary relief
# 4       Enhanced Acquisitions, LLC          Closed with explanation
#
#   Timely response? Consumer disputed?
# 0              Yes                NaN
# 1              Yes                NaN
# 2              Yes                NaN
# 3              Yes                NaN
# 4              Yes                NaN

# %%
date_series = consumer_complaints.pop('Date received')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/Cameron/Documents/python/homework/.direnv/python-3.5.1/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1875             try:
# -> 1876                 return self._engine.get_loc(key)
#    1877             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4027)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3891)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12408)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12359)()
#
# KeyError: 'Date received'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-2bcd3c469265> in <module>()
# ----> 1 date_series = consumer_complaints.pop('Date received')
#
# /Users/Cameron/Documents/python/homework/.direnv/python-3.5.1/lib/python3.5/site-packages/pandas/core/generic.py in pop(self, item)
#     503         Return item and drop from frame. Raise KeyError if not found.
#     504         """
# --> 505         result = self[item]
#     506         del self[item]
#     507         try:
#
# /Users/Cameron/Documents/python/homework/.direnv/python-3.5.1/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1990             return self._getitem_multilevel(key)
#    1991         else:
# -> 1992             return self._getitem_column(key)
#    1993
#    1994     def _getitem_column(self, key):
#
# /Users/Cameron/Documents/python/homework/.direnv/python-3.5.1/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    1997         # get column
#    1998         if self.columns.is_unique:
# -> 1999             return self._get_item_cache(key)
#    2000
#    2001         # duplicate columns & possible reduce dimensionality
#
# /Users/Cameron/Documents/python/homework/.direnv/python-3.5.1/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1343         res = cache.get(item)
#    1344         if res is None:
# -> 1345             values = self._data.get(item)
#    1346             res = self._box_item_values(item, values)
#    1347             cache[item] = res
#
# /Users/Cameron/Documents/python/homework/.direnv/python-3.5.1/lib/python3.5/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3223
#    3224             if not isnull(item):
# -> 3225                 loc = self.items.get_loc(item)
#    3226             else:
#    3227                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/Cameron/Documents/python/homework/.direnv/python-3.5.1/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1876                 return self._engine.get_loc(key)
#    1877             except KeyError:
# -> 1878                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1879
#    1880         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4027)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3891)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12408)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12359)()
#
# KeyError: 'Date received'

# %%
consumer_complaints.index = pd.to_datetime(date_series, format='%m/%d/%Y')
consumer_complaints = consumer_complaints.rename(columns={"Complaint ID":"ID"}).copy()
consumer_complaints.head()
# Out:
#                     ID          Product Sub-product  \
# Date received
# 2014-12-31     1177167  Debt collection         NaN
# 2014-12-31     1177166  Debt collection         NaN
# 2014-12-31     1177165  Debt collection         NaN
# 2014-12-31     1177164  Debt collection         NaN
# 2014-12-31     1177163  Debt collection         NaN
#
#                                                Issue         Sub-issue State  \
# Date received
# 2014-12-31     Cont'd attempts collect debt not owed  Debt is not mine    TX
# 2014-12-31     Cont'd attempts collect debt not owed  Debt is not mine    TX
# 2014-12-31     Cont'd attempts collect debt not owed  Debt is not mine    TX
# 2014-12-31     Cont'd attempts collect debt not owed  Debt is not mine    TX
# 2014-12-31     Cont'd attempts collect debt not owed  Debt is not mine    TX
#
#                ZIP code Submitted via Date sent to company  \
# Date received
# 2014-12-31      77068.0           Web           12/31/2014
# 2014-12-31      77068.0           Web           12/31/2014
# 2014-12-31      77068.0           Web           12/31/2014
# 2014-12-31      77068.0           Web           12/31/2014
# 2014-12-31      77068.0           Web           12/31/2014
#
#                                        Company  \
# Date received
# 2014-12-31      Ad Astra Recovery Services Inc
# 2014-12-31     Unique Management Services, Inc
# 2014-12-31                    CL Holdings, LLC
# 2014-12-31      Enhanced Recovery Company, LLC
# 2014-12-31          Enhanced Acquisitions, LLC
#
#                               Company response Timely response?  \
# Date received
# 2014-12-31             Closed with explanation              Yes
# 2014-12-31             Closed with explanation              Yes
# 2014-12-31         Closed with monetary relief              Yes
# 2014-12-31     Closed with non-monetary relief              Yes
# 2014-12-31             Closed with explanation              Yes
#
#               Consumer disputed?
# Date received
# 2014-12-31                   NaN
# 2014-12-31                   NaN
# 2014-12-31                   NaN
# 2014-12-31                   NaN
# 2014-12-31                   NaN

# %%
product_count = consumer_complaints[['Product', 'ID']].copy()

# %%
product_count
# Out:
#                                Product       ID
# Date received
# 2014-12-31             Debt collection  1177167
# 2014-12-31             Debt collection  1177166
# 2014-12-31             Debt collection  1177165
# 2014-12-31             Debt collection  1177164
# 2014-12-31             Debt collection  1177163
# 2014-12-31             Debt collection  1177162
# 2014-12-31                 Credit card  1177154
# 2014-12-31             Debt collection  1177143
# 2014-12-31             Debt collection  1177140
# 2014-12-31             Debt collection  1177139
# 2014-12-31             Debt collection  1177136
# 2014-12-31     Bank account or service  1177128
# 2014-12-31             Debt collection  1177125
# 2014-12-31             Debt collection  1177124
# 2014-12-31             Debt collection  1177116
# 2014-12-31             Debt collection  1177114
# 2014-12-31            Credit reporting  1177196
# 2014-12-31             Debt collection  1177113
# 2014-12-31             Debt collection  1177112
# 2014-12-31                 Credit card  1177101
# 2014-12-31     Bank account or service  1177100
# 2014-12-31            Credit reporting  1177095
# 2014-12-31            Credit reporting  1177091
# 2014-12-31                    Mortgage  1177085
# 2014-12-31                    Mortgage  1177077
# 2014-12-31                    Mortgage  1177066
# 2014-12-31             Money transfers  1177062
# 2014-12-31     Bank account or service  1177057
# 2014-12-31     Bank account or service  1177056
# 2014-12-31             Debt collection  1177037
# ...                                ...      ...
# 2014-12-01                    Mortgage  1136225
# 2014-12-01            Credit reporting  1136223
# 2014-12-01            Credit reporting  1136222
# 2014-12-01            Credit reporting  1136221
# 2014-12-01             Debt collection  1136220
# 2014-12-01                    Mortgage  1136219
# 2014-12-01                    Mortgage  1136218
# 2014-12-01            Credit reporting  1136212
# 2014-12-01            Credit reporting  1136211
# 2014-12-01            Credit reporting  1136210
# 2014-12-01                    Mortgage  1136208
# 2014-12-01             Debt collection  1136205
# 2014-12-01                 Credit card  1136710
# 2014-12-01             Debt collection  1136200
# 2014-12-01            Credit reporting  1136195
# 2014-12-01            Credit reporting  1136194
# 2014-12-01            Credit reporting  1136193
# 2014-12-01                    Mortgage  1136192
# 2014-12-01                 Credit card  1136190
# 2014-12-01                 Credit card  1136188
# 2014-12-01               Consumer loan  1136185
# 2014-12-01                    Mortgage  1136183
# 2014-12-01             Debt collection  1136180
# 2014-12-01             Debt collection  1136175
# 2014-12-01            Credit reporting  1136173
# 2014-12-01                    Mortgage  1136172
# 2014-12-01                    Mortgage  1136170
# 2014-12-01                    Mortgage  1136169
# 2014-12-01                    Mortgage  1136162
# 2014-12-01                    Mortgage  1136158
#
# [11543 rows x 2 columns]

# %%
product_count = product_count.groupby("Product").size()

# %%
product_count = product_count.sort_values(ascending=False)

# %%
product_count
# Out:
# Product
# Mortgage                   3002
# Debt collection            2942
# Credit reporting           2113
# Bank account or service    1136
# Credit card                1100
# Consumer loan               578
# Student loan                340
# Payday loan                 141
# Money transfers             107
# Prepaid card                 70
# Other financial service      14
# dtype: int64

# %%
company_complaints = consumer_complaints[['Company', 'ID']].copy()

# %%
company_complaints.head()
# Out:
#                                        Company       ID
# Date received
# 2014-12-31      Ad Astra Recovery Services Inc  1177167
# 2014-12-31     Unique Management Services, Inc  1177166
# 2014-12-31                    CL Holdings, LLC  1177165
# 2014-12-31      Enhanced Recovery Company, LLC  1177164
# 2014-12-31          Enhanced Acquisitions, LLC  1177163
